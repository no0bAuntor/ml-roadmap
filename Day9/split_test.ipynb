# %%
import pandas as pd

file_path = "list.xlsx"
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#    Exam Score  Experience (Years)  Salary
# 0          60                   1   40000
# 1          53                   2   33000
# 2          60                   3   42000
# 3          50                   4   35000
# 4          71                   5   70000

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Exam Score"], df["Salary"])

# %%
x = df[["Exam Score", "Experience (Years)"]]
y = df[["Salary"]]
x
# Out:
#     Exam Score  Experience (Years)
# 0           60                   1
# 1           53                   2
# 2           60                   3
# 3           50                   4
# 4           71                   5
# 5           49                   6
# 6           50                   7
# 7           68                   8
# 8           65                   9
# 9           61                  10
# 10          51                  11
# 11          55                  12
# 12          50                  13
# 13          45                  14
# 14          50                  15
# 15          63                  16
# 16          63                  17
# 17          35                  18
# 18          66                  19
# 19          78                  20

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#     Exam Score  Experience (Years)
# 8           65                   9
# 5           49                   6
# 11          55                  12
# 3           50                   4
# 18          66                  19
# 16          63                  17
# 13          45                  14
# 2           60                   3
# 9           61                  10
# 19          78                  20
# 4           71                   5
# 12          50                  13
# 7           68                   8
# 10          51                  11
# 14          50                  15
# 6           50                   7

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([[47349.84010747],
#        [15939.57287104],
#        [60392.76209504],
#        [36508.658116  ]])

# %%
y_test
# Out:
#     Salary
# 0    40000
# 17   29500
# 15   65500
# 1    33000

# %%
clf.score(x_test, y_test)
# Out:
# 0.6517959743946409
